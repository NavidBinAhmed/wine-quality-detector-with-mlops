# %%
print('navid')
# Out:
# navid

# %%
print('sakin')
# Out:
# sakin

# %%
# %pwd
# Out:
# 'h:\\Projects\\wine-quality-detector-with-mlops\\research'

# %%
import os
os.chdir('../')

# %%
# %pwd
# Out:
# 'h:\\Projects\\wine-quality-detector-with-mlops'
